# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print "OpenCV Version : %s " % cv2.__version__
# Out:
# OpenCV Version : 2.4.11

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# #### 1 - Não. O histograma mostra apenas 1/5 da gama de cores que podem ser aproveitados.

# %% [markdown]
# #### 2 - Para equalizar o histograma que a cumulativa seja uma função linear no gráfico, devemos multiplicar os valores do array de rintin_gray pelo máximo do x do histograma com o valor máx encontrado.

# %%
m = max(rintin_gray.flatten())
maximo = max(bins)/m

# %%
rintin_gray2 = [line * maximo for line in rintin_gray]
#for line in rintin_gray:
 #   line*maximo

# %%
rintin_gray2 = [np.asarray(line) for line in rintin_gray2]
rintin_gray2 = np.asarray(rintin_gray2)

# %%
hist,bins = np.histogram(rintin_gray2.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray2.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ### 3 -

# %%
plt.imshow(rintin_gray2, cmap="Greys_r")

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 2.Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %% [markdown]
# ## 1 - Para fazer a análise, devemos separar os canais e fazer o estudo de cada histograma separadamente.

# %%
corredor = cv2.imread("hall_box_battery1.jpg")
corredor_rgb = cv2.cvtColor(corredor, cv2.COLOR_BGR2RGB)

# %%
corredor_rgb.shape
# Out:
# (3006, 5344, 3)

# %%
corredor_r = corredor_rgb[:,:,0]
corredor_g = corredor_rgb[:,:,1]
corredor_b = corredor_rgb[:,:,2]

# %% [markdown]
# ### Sabendo que o histograma plota proporcionalmente a área da imagem, conseguimos identificar qual é a caixa azul pela quantidade de pixels(poucos) que ela tem. No caso da caixa vermelha, não conseguimos identifica-la pois existem outras coisas na imagem que contém uma quantidade de pixels que não são diferentes o suficiente para se distinguir dela.

# %%
plt.imshow(corredor_b, cmap="Greys_r", vmin=0, vmax=255)

# %% [markdown]
# ## Histograma dos pixels azuis da imagem

# %%
hist,bins = np.histogram(corredor_b.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

#plt.plot(cdf_normalized, color = 'b')
plt.hist(corredor_b.flatten(),256,[0,256], color = 'b')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Histograma pixels vermelhos

# %%
hist,bins = np.histogram(corredor_r.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

#plt.plot(cdf_normalized, color = 'b')
plt.hist(corredor_r.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ### 2 -

# %%
r_g = corredor_r - corredor_g
b_g = corredor_b - corredor_g

# %%
def pixels_red(a):
    if a > 135 and a < 180:
        return 255
    else:
        return 0
    
pixels_red_v = np.vectorize(pixels_red)

pixels_box = [pixels_red_v(line) for line in r_g]
pixels_box = np.asarray (pixels_box)

plt.imshow (pixels_box, cmap = "Greys_r")
